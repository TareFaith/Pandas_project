# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option ('max_columns', 200)

# %%
df= pd.read_csv("D:\DataScience\Trees-data.csv")

# %%
df.head(5)
# Out:
#                          measurement_id       measurement_type  auto_diameter  \
# 0  59d3059e-e950-48eb-b2af-aeca583742ab  tree_measurement_auto             42
# 1  d827bcf5-3fe3-4f46-8274-7a640ef4bb9d  tree_measurement_auto            233
# 2  0d129aa4-e247-4508-9b9d-2d4c5718c5e2  tree_measurement_auto            180
# 3  b0bbb634-5ea1-4bc2-95a7-09d0465e6ac3  tree_measurement_auto             94
# 4  54efcd63-e78c-49d9-af8e-3c02c0e485b2  tree_measurement_auto             82
#
#    manualdiameter  duration              manufacturer          model  \
# 0          4287.0     29104                      itel     itel W5005
# 1           250.0      6901  INFINIX MOBILITY LIMITED  Infinix X688B
# 2           177.0      5676  INFINIX MOBILITY LIMITED  Infinix X688B
# 3           100.0      2493  INFINIX MOBILITY LIMITED  Infinix X688B
# 4            59.0      3203  INFINIX MOBILITY LIMITED  Infinix X688B
#
#   android_version  total_ram  free_ram  \
# ...

# %%
df.shape
# Out:
# (1525, 15)

# %%
df.columns
# Out:
# Index(['measurement_id', 'measurement_type', 'auto_diameter', 'manualdiameter',
#        'duration', 'manufacturer', 'model', 'android_version', 'total_ram',
#        'free_ram', 'sensors', 'screen_resolution', 'camera_resolution',
#        'advertising_id', 'one'],
#       dtype='object')

# %%
df.dtypes
# Out:
# measurement_id        object
# measurement_type      object
# auto_diameter          int64
# manualdiameter       float64
# duration               int64
# manufacturer          object
# model                 object
# android_version       object
# total_ram              int64
# free_ram               int64
# sensors               object
# screen_resolution     object
# camera_resolution     object
# advertising_id        object
# one                    int64
# dtype: object

# %%
df.describe()
# Out:
#        auto_diameter  manualdiameter      duration    total_ram     free_ram  \
# count    1525.000000     1525.000000   1525.000000  1525.000000  1525.000000
# mean       81.439344      105.034157   2377.272131  3764.410492  1073.319344
# std        32.924271      576.899805   1319.656249   110.269376    99.162852
# min         5.000000        5.000000    856.000000   924.000000   393.000000
# 25%        60.000000       63.000000   1212.000000  3750.000000  1020.000000
# 50%        78.000000       80.000000   2614.000000  3750.000000  1036.000000
# 75%        95.000000       98.000000   3092.000000  3821.000000  1213.000000
# max       377.000000    20796.000000  29104.000000  3821.000000  1435.000000
#
#           one
# count  1525.0
# mean      1.0
# std       0.0
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0

# %%
df[['measurement_id', 'measurement_type',
    'auto_diameter', 'manualdiameter',
       'duration', 'manufacturer', 'model', 
    'android_version', 'total_ram',
       'free_ram', 'sensors', 
    'screen_resolution', 'camera_resolution',
       'advertising_id', 
    'one']]
# Out:
#                             measurement_id       measurement_type  \
# 0     59d3059e-e950-48eb-b2af-aeca583742ab  tree_measurement_auto
# 1     d827bcf5-3fe3-4f46-8274-7a640ef4bb9d  tree_measurement_auto
# 2     0d129aa4-e247-4508-9b9d-2d4c5718c5e2  tree_measurement_auto
# 3     b0bbb634-5ea1-4bc2-95a7-09d0465e6ac3  tree_measurement_auto
# 4     54efcd63-e78c-49d9-af8e-3c02c0e485b2  tree_measurement_auto
# ...                                    ...                    ...
# 1520  8b22c1bf-5de6-4e42-905e-68b38846baee  tree_measurement_auto
# 1521  9ea8b670-7aa1-468d-827e-a36e01bedd3c  tree_measurement_auto
# 1522  332ddb59-a9b2-4134-b209-51ce63296e60  tree_measurement_auto
# 1523  d9f6d96b-3b99-44fe-8966-ae3574c91d43  tree_measurement_auto
# 1524  bf7cf5cd-5e7a-42bc-a9c0-ec5e27034f1f  tree_measurement_auto
#
#       auto_diameter  manualdiameter  duration              manufacturer  \
# 0                42          4287.0     29104                      itel
# ...

# %%
df.columns
# Out:
# Index(['measurement_id', 'measurement_type', 'auto_diameter', 'manualdiameter',
#        'duration', 'manufacturer', 'model', 'android_version', 'total_ram',
#        'free_ram', 'sensors', 'screen_resolution', 'camera_resolution',
#        'advertising_id', 'one'],
#       dtype='object')

# %%
df.rename(columns={'manualdiameter':'manual_diameter', 'auto_diameter': 'auto_Diameter'})
# Out:
#                             measurement_id       measurement_type  \
# 0     59d3059e-e950-48eb-b2af-aeca583742ab  tree_measurement_auto
# 1     d827bcf5-3fe3-4f46-8274-7a640ef4bb9d  tree_measurement_auto
# 2     0d129aa4-e247-4508-9b9d-2d4c5718c5e2  tree_measurement_auto
# 3     b0bbb634-5ea1-4bc2-95a7-09d0465e6ac3  tree_measurement_auto
# 4     54efcd63-e78c-49d9-af8e-3c02c0e485b2  tree_measurement_auto
# ...                                    ...                    ...
# 1520  8b22c1bf-5de6-4e42-905e-68b38846baee  tree_measurement_auto
# 1521  9ea8b670-7aa1-468d-827e-a36e01bedd3c  tree_measurement_auto
# 1522  332ddb59-a9b2-4134-b209-51ce63296e60  tree_measurement_auto
# 1523  d9f6d96b-3b99-44fe-8966-ae3574c91d43  tree_measurement_auto
# 1524  bf7cf5cd-5e7a-42bc-a9c0-ec5e27034f1f  tree_measurement_auto
#
#       auto_Diameter  manual_diameter  duration              manufacturer  \
# 0                42           4287.0     29104                      itel
# ...

# %%
df.isna().sum()
# Out:
# measurement_id       0
# measurement_type     0
# auto_diameter        0
# manualdiameter       0
# duration             0
# manufacturer         0
# model                0
# android_version      0
# total_ram            0
# free_ram             0
# sensors              0
# screen_resolution    0
# camera_resolution    0
# advertising_id       0
# one                  0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1520    False
# 1521    False
# 1522    False
# 1523    False
# 1524    False
# Length: 1525, dtype: bool

# %%
df.shape
# Out:
# (1525, 15)

# %%
df['auto_Diameter'].plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'auto_Diameter'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ax = df['auto_diameter'].plot(kind='hist', title='Tree_Diameter')
ax.set_xlabel('Diameter')
ax.set_ylabel('Frequency_Values')
# Out:
# Text(0, 0.5, 'Frequency_Values')

# %%
df['free_ram'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.plot(kind='scatter',x='manufacturer', y='auto_diameter',title='diameter vs Manufacturer')
plt.show()

# %%
sns.scatterplot(x = 'manufacturer',
                y = 'auto_diameter',
                hue='duration',
                data =df)
# Out:
# <AxesSubplot:xlabel='manufacturer', ylabel='auto_diameter'>

# %%
df_corr = df[['duration','screen_resolution','android_version','total_ram','camera_resolution','free_ram',]].dropna().corr()
df_corr
# Out:
#            duration  total_ram  free_ram
# duration   1.000000  -0.423343  0.023025
# total_ram -0.423343   1.000000  0.549005
# free_ram   0.023025   0.549005  1.000000

# %%
sns.heatmap(df_corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df[['manufacturer']].value_counts()
# Out:
# manufacturer
# Xiaomi                      808
# INFINIX MOBILITY LIMITED    714
# OPPO                          1
# itel                          1
# samsung                       1
# dtype: int64
